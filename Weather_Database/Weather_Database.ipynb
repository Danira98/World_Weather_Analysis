# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size= 2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 738

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url =  "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]     
        city_description = city_weather["weather"][0]["description"]    
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),                         
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description})
        
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nuuk
# Processing Record 2 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | hamilton
# Processing Record 5 of Set 1 | lagoa
# Processing Record 6 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 1 | solnechnyy
# Processing Record 8 of Set 1 | norman wells
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | hasaki
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | dingle
# Processing Record 14 of Set 1 | khatanga
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | susanville
# Processing Record 17 of Set 1 | chinhoyi
# Processing Record 18 of Set 1 | bethel
# Processing Record 19 of Set 1 | nanortalik
# Processing Record 20 of Set 1 | luderitz
# Processing Record 21 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | saskylakh
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | makakilo city
# Processing Record 30 of Set 1 | christiansburg
# Processing Record 31 of Set 1 | avera
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | omsukchan
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | kavieng
# Processing Record 41 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 1 | belaya gora
# Processing Record 43 of Set 1 | borogontsy
# Processing Record 44 of Set 1 | kaitangata
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | severo-kurilsk
# Processing Record 47 of Set 1 | talnakh
# Processing Record 48 of Set 1 | tasiilaq
# Processing Record 49 of Set 1 | thompson
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | wukari
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | cap-aux-meules
# Processing Record 5 of Set 2 | machico
# Processing Record 6 of Set 2 | san patricio
# Processing Record 7 of Set 2 | kimbe
# Processing Record 8 of Set 2 | marsh harbour
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | port hardy
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | tazovskiy
# Processing Record 13 of Set 2 | sibolga
# Processing Record 14 of Set 2 | mucuri
# Processing Record 15 of Set 2 | fairbanks
# Processing Record 16 of Set 2 | bambous virieux
# Processing Record 17 of Set 2 | souillac
# Processing Record 18 of Set 2 | hounde
# Processing Record 19 of Set 2 | dunedin
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | grand forks
# Processing Record 22 of Set 2 | nemuro
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | kavaratti
# Processing Record 25 of Set 2 | pangnirtung
# Processing Record 26 of Set 2 | mongo
# Processing Record 27 of Set 2 | dali
# Processing Record 28 of Set 2 | kahului
# Processing Record 29 of Set 2 | leningradskiy
# Processing Record 30 of Set 2 | georgetown
# Processing Record 31 of Set 2 | sambava
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | port macquarie
# Processing Record 34 of Set 2 | faanui
# Processing Record 35 of Set 2 | balkanabat
# Processing Record 36 of Set 2 | wanning
# Processing Record 37 of Set 2 | sao joao da barra
# Processing Record 38 of Set 2 | hualmay
# Processing Record 39 of Set 2 | puerto palomas
# Processing Record 40 of Set 2 | una
# Processing Record 41 of Set 2 | mackenzie
# Processing Record 42 of Set 2 | pachino
# Processing Record 43 of Set 2 | isabela
# Processing Record 44 of Set 2 | saldanha
# Processing Record 45 of Set 2 | avarua
# Processing Record 46 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 2 | nasice
# Processing Record 48 of Set 2 | isangel
# Processing Record 49 of Set 2 | pombia
# Processing Record 50 of Set 2 | tigil
# Processing Record 1 of Set 3 | upernavik
# Processing Record 2 of Set 3 | dedougou
# Processing Record 3 of Set 3 | nongstoin
# Processing Record 4 of Set 3 | bengkulu
# Processing Record 5 of Set 3 | mahebourg
# Processing Record 6 of Set 3 | cape town
# Processing Record 7 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 3 | lavrentiya
# Processing Record 9 of Set 3 | port lincoln
# Processing Record 10 of Set 3 | nagato
# Processing Record 11 of Set 3 | barrow
# Processing Record 12 of Set 3 | mitsamiouli
# Processing Record 13 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 3 | tiksi
# Processing Record 15 of Set 3 | dikson
# Processing Record 16 of Set 3 | los llanos de aridane
# Processing Record 17 of Set 3 | batagay
# Processing Record 18 of Set 3 | kruisfontein
# Processing Record 19 of Set 3 | zunyi
# Processing Record 20 of Set 3 | nikolayevka
# Processing Record 21 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 3 | moree
# Processing Record 23 of Set 3 | nikolskoye
# Processing Record 24 of Set 3 | turkistan
# Processing Record 25 of Set 3 | naryan-mar
# Processing Record 26 of Set 3 | annau
# Processing Record 27 of Set 3 | east london
# Processing Record 28 of Set 3 | khandyga
# Processing Record 29 of Set 3 | sitka
# Processing Record 30 of Set 3 | florida
# Processing Record 31 of Set 3 | carnarvon
# Processing Record 32 of Set 3 | romny
# Processing Record 33 of Set 3 | broome
# Processing Record 34 of Set 3 | lander
# Processing Record 35 of Set 3 | sobolevo
# Processing Record 36 of Set 3 | shizuishan
# Processing Record 37 of Set 3 | acapulco
# Processing Record 38 of Set 3 | maragogi
# Processing Record 39 of Set 3 | lebu
# Processing Record 40 of Set 3 | nchelenge
# Processing Record 41 of Set 3 | margate
# Processing Record 42 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 43 of Set 3 | rosarito
# Processing Record 44 of Set 3 | richards bay
# Processing Record 45 of Set 3 | ixtapa
# Processing Record 46 of Set 3 | ponta do sol
# Processing Record 47 of Set 3 | mecca
# Processing Record 48 of Set 3 | chokurdakh
# Processing Record 49 of Set 3 | aviles
# Processing Record 50 of Set 3 | kenai
# Processing Record 1 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 4 | half moon bay
# Processing Record 3 of Set 4 | norfolk
# Processing Record 4 of Set 4 | lichuan
# Processing Record 5 of Set 4 | saint george
# Processing Record 6 of Set 4 | vuktyl
# Processing Record 7 of Set 4 | yellowknife
# Processing Record 8 of Set 4 | elliot lake
# Processing Record 9 of Set 4 | hami
# Processing Record 10 of Set 4 | carutapera
# Processing Record 11 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 4 | lalomanu
# City not found. Skipping...
# Processing Record 13 of Set 4 | alto araguaia
# Processing Record 14 of Set 4 | adrar
# Processing Record 15 of Set 4 | santa fe
# Processing Record 16 of Set 4 | tuatapere
# Processing Record 17 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 18 of Set 4 | saint-philippe
# Processing Record 19 of Set 4 | yamada
# Processing Record 20 of Set 4 | ornes
# Processing Record 21 of Set 4 | arraial do cabo
# Processing Record 22 of Set 4 | lao cai
# Processing Record 23 of Set 4 | torbay
# Processing Record 24 of Set 4 | ust-ilimsk
# Processing Record 25 of Set 4 | coquimbo
# Processing Record 26 of Set 4 | okhotsk
# Processing Record 27 of Set 4 | prainha
# Processing Record 28 of Set 4 | boende
# Processing Record 29 of Set 4 | concarneau
# Processing Record 30 of Set 4 | elko
# Processing Record 31 of Set 4 | pushkinskiye gory
# Processing Record 32 of Set 4 | nigde
# Processing Record 33 of Set 4 | lompoc
# Processing Record 34 of Set 4 | san quintin
# Processing Record 35 of Set 4 | grand gaube
# Processing Record 36 of Set 4 | kloulklubed
# Processing Record 37 of Set 4 | bucerias
# Processing Record 38 of Set 4 | grindavik
# Processing Record 39 of Set 4 | mizpe ramon
# City not found. Skipping...
# Processing Record 40 of Set 4 | opuwo
# Processing Record 41 of Set 4 | lorengau
# Processing Record 42 of Set 4 | alyangula
# Processing Record 43 of Set 4 | katherine
# Processing Record 44 of Set 4 | roald
# Processing Record 45 of Set 4 | krasnorechenskiy
# Processing Record 46 of Set 4 | skagastrond
# City not found. Skipping...
# Processing Record 47 of Set 4 | ribeira grande
# Processing Record 48 of Set 4 | anchorage
# Processing Record 49 of Set 4 | tautira
# Processing Record 50 of Set 4 | vardo
# Processing Record 1 of Set 5 | sept-iles
# Processing Record 2 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 5 | lardos
# Processing Record 4 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 5 of Set 5 | freeport
# Processing Record 6 of Set 5 | demyansk
# Processing Record 7 of Set 5 | sur
# Processing Record 8 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 5 | ukiah
# Processing Record 10 of Set 5 | buala
# Processing Record 11 of Set 5 | zalantun
# Processing Record 12 of Set 5 | nsunga
# Processing Record 13 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 5 | college
# Processing Record 15 of Set 5 | turayf
# Processing Record 16 of Set 5 | saint-georges
# Processing Record 17 of Set 5 | la ronge
# Processing Record 18 of Set 5 | eston
# Processing Record 19 of Set 5 | aklavik
# Processing Record 20 of Set 5 | juneau
# Processing Record 21 of Set 5 | daru
# Processing Record 22 of Set 5 | san luis
# Processing Record 23 of Set 5 | qandala
# Processing Record 24 of Set 5 | saint anthony
# Processing Record 25 of Set 5 | gravdal
# Processing Record 26 of Set 5 | morant bay
# Processing Record 27 of Set 5 | pag
# Processing Record 28 of Set 5 | cordoba
# Processing Record 29 of Set 5 | khani
# Processing Record 30 of Set 5 | sri aman
# Processing Record 31 of Set 5 | rjukan
# Processing Record 32 of Set 5 | charlestown
# Processing Record 33 of Set 5 | vostok
# Processing Record 34 of Set 5 | yuci
# Processing Record 35 of Set 5 | north bend
# Processing Record 36 of Set 5 | arboletes
# Processing Record 37 of Set 5 | olinda
# Processing Record 38 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 40 of Set 5 | pisco
# Processing Record 41 of Set 5 | paamiut
# Processing Record 42 of Set 5 | rio grande
# Processing Record 43 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 5 | kunya
# Processing Record 45 of Set 5 | alofi
# Processing Record 46 of Set 5 | rawson
# Processing Record 47 of Set 5 | moche
# Processing Record 48 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 49 of Set 5 | beringovskiy
# Processing Record 50 of Set 5 | masuda
# Processing Record 1 of Set 6 | codrington
# Processing Record 2 of Set 6 | shimoda
# Processing Record 3 of Set 6 | new norfolk
# Processing Record 4 of Set 6 | castro
# Processing Record 5 of Set 6 | riyadh
# Processing Record 6 of Set 6 | ayer itam
# City not found. Skipping...
# Processing Record 7 of Set 6 | coffs harbour
# Processing Record 8 of Set 6 | nouakchott
# Processing Record 9 of Set 6 | lazaro cardenas
# Processing Record 10 of Set 6 | skibbereen
# Processing Record 11 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 6 | fort nelson
# Processing Record 13 of Set 6 | bakal
# Processing Record 14 of Set 6 | zhuhai
# Processing Record 15 of Set 6 | heihe
# Processing Record 16 of Set 6 | yaan
# Processing Record 17 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 6 | arlit
# Processing Record 19 of Set 6 | krasnoarmeysk
# Processing Record 20 of Set 6 | jiujiang
# Processing Record 21 of Set 6 | atar
# Processing Record 22 of Set 6 | salalah
# Processing Record 23 of Set 6 | rantepao
# Processing Record 24 of Set 6 | nichinan
# Processing Record 25 of Set 6 | kuching
# Processing Record 26 of Set 6 | kuhdasht
# Processing Record 27 of Set 6 | qeshm
# Processing Record 28 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 6 | chepareria
# Processing Record 30 of Set 6 | ucluelet
# Processing Record 31 of Set 6 | kulhudhuffushi
# Processing Record 32 of Set 6 | kot kapura
# Processing Record 33 of Set 6 | ilinskiy
# Processing Record 34 of Set 6 | esperance
# Processing Record 35 of Set 6 | camana
# Processing Record 36 of Set 6 | shilka
# Processing Record 37 of Set 6 | klaksvik
# Processing Record 38 of Set 6 | haines junction
# Processing Record 39 of Set 6 | plainview
# Processing Record 40 of Set 6 | goya
# Processing Record 41 of Set 6 | padang
# Processing Record 42 of Set 6 | leshukonskoye
# Processing Record 43 of Set 6 | ambilobe
# Processing Record 44 of Set 6 | liusha
# Processing Record 45 of Set 6 | bilibino
# Processing Record 46 of Set 6 | harqalah
# Processing Record 47 of Set 6 | ambulu
# Processing Record 48 of Set 6 | huarmey
# Processing Record 49 of Set 6 | kualakapuas
# Processing Record 50 of Set 6 | provideniya
# Processing Record 1 of Set 7 | samarai
# Processing Record 2 of Set 7 | katsuura
# Processing Record 3 of Set 7 | vila velha
# Processing Record 4 of Set 7 | bodden town
# Processing Record 5 of Set 7 | kandrian
# Processing Record 6 of Set 7 | herat
# Processing Record 7 of Set 7 | wanlaweyn
# Processing Record 8 of Set 7 | arman
# Processing Record 9 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 7 | ocos
# Processing Record 11 of Set 7 | saint-joseph
# Processing Record 12 of Set 7 | anadyr
# Processing Record 13 of Set 7 | havoysund
# Processing Record 14 of Set 7 | asau
# Processing Record 15 of Set 7 | general roca
# Processing Record 16 of Set 7 | alice springs
# Processing Record 17 of Set 7 | toamasina
# Processing Record 18 of Set 7 | weihe
# Processing Record 19 of Set 7 | chuy
# Processing Record 20 of Set 7 | hofn
# Processing Record 21 of Set 7 | yumen
# Processing Record 22 of Set 7 | ihosy
# Processing Record 23 of Set 7 | santander
# Processing Record 24 of Set 7 | nome
# Processing Record 25 of Set 7 | senador jose porfirio
# Processing Record 26 of Set 7 | tual
# Processing Record 27 of Set 7 | udachnyy
# Processing Record 28 of Set 7 | newport
# Processing Record 29 of Set 7 | buraydah
# Processing Record 30 of Set 7 | baruun-urt
# Processing Record 31 of Set 7 | tiznit
# Processing Record 32 of Set 7 | cabras
# Processing Record 33 of Set 7 | manono
# Processing Record 34 of Set 7 | hoshcha
# Processing Record 35 of Set 7 | rio gallegos
# Processing Record 36 of Set 7 | rosetown
# Processing Record 37 of Set 7 | erzin
# Processing Record 38 of Set 7 | bonavista
# Processing Record 39 of Set 7 | yerbogachen
# Processing Record 40 of Set 7 | cockburn town
# Processing Record 41 of Set 7 | esmeralda
# Processing Record 42 of Set 7 | urumqi
# Processing Record 43 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 44 of Set 7 | touros
# Processing Record 45 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 7 | tanem
# Processing Record 47 of Set 7 | geraldton
# Processing Record 48 of Set 7 | murgab
# Processing Record 49 of Set 7 | namibe
# Processing Record 50 of Set 7 | chilca
# Processing Record 1 of Set 8 | nishihara
# Processing Record 2 of Set 8 | jian
# Processing Record 3 of Set 8 | santiago de cao
# Processing Record 4 of Set 8 | makushino
# Processing Record 5 of Set 8 | chicama
# Processing Record 6 of Set 8 | fortuna
# Processing Record 7 of Set 8 | kruje
# Processing Record 8 of Set 8 | roman
# Processing Record 9 of Set 8 | henties bay
# Processing Record 10 of Set 8 | yar-sale
# Processing Record 11 of Set 8 | nouadhibou
# Processing Record 12 of Set 8 | maturin
# Processing Record 13 of Set 8 | safonovo
# Processing Record 14 of Set 8 | peterborough
# Processing Record 15 of Set 8 | meulaboh
# Processing Record 16 of Set 8 | shahrud
# Processing Record 17 of Set 8 | muisne
# Processing Record 18 of Set 8 | sorata
# Processing Record 19 of Set 8 | puerto madero
# Processing Record 20 of Set 8 | makat
# Processing Record 21 of Set 8 | chitrakonda
# Processing Record 22 of Set 8 | seoul
# Processing Record 23 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 8 | benjamin hill
# Processing Record 25 of Set 8 | abha
# Processing Record 26 of Set 8 | dalbandin
# Processing Record 27 of Set 8 | lovozero
# Processing Record 28 of Set 8 | hargeysa
# Processing Record 29 of Set 8 | slave lake
# Processing Record 30 of Set 8 | jalu
# Processing Record 31 of Set 8 | dhidhdhoo
# Processing Record 32 of Set 8 | cherskiy
# Processing Record 33 of Set 8 | siteki
# Processing Record 34 of Set 8 | kolokani
# Processing Record 35 of Set 8 | myaundzha
# Processing Record 36 of Set 8 | gashua
# Processing Record 37 of Set 8 | hambantota
# Processing Record 38 of Set 8 | lipin bor
# Processing Record 39 of Set 8 | juegang
# Processing Record 40 of Set 8 | ratnagiri
# Processing Record 41 of Set 8 | necochea
# Processing Record 42 of Set 8 | vao
# Processing Record 43 of Set 8 | marawi
# Processing Record 44 of Set 8 | el balyana
# City not found. Skipping...
# Processing Record 45 of Set 8 | mahajanga
# Processing Record 46 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 8 | camacha
# Processing Record 48 of Set 8 | zwedru
# Processing Record 49 of Set 8 | ransang
# Processing Record 50 of Set 8 | jawhar
# Processing Record 1 of Set 9 | sinnamary
# Processing Record 2 of Set 9 | pevek
# Processing Record 3 of Set 9 | jubb jannin
# City not found. Skipping...
# Processing Record 4 of Set 9 | sakakah
# Processing Record 5 of Set 9 | timra
# Processing Record 6 of Set 9 | portland
# Processing Record 7 of Set 9 | roebourne
# Processing Record 8 of Set 9 | severnyy
# Processing Record 9 of Set 9 | saint-pierre
# Processing Record 10 of Set 9 | hadejia
# Processing Record 11 of Set 9 | uthal
# Processing Record 12 of Set 9 | melfi
# Processing Record 13 of Set 9 | jauharabad
# Processing Record 14 of Set 9 | cabo san lucas
# Processing Record 15 of Set 9 | quatre cocos
# Processing Record 16 of Set 9 | bikaner
# Processing Record 17 of Set 9 | deulgaon raja
# Processing Record 18 of Set 9 | puerto escondido
# Processing Record 19 of Set 9 | san andres
# Processing Record 20 of Set 9 | havelock
# Processing Record 21 of Set 9 | fukue
# Processing Record 22 of Set 9 | luebo
# Processing Record 23 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 24 of Set 9 | batticaloa
# Processing Record 25 of Set 9 | cidreira
# Processing Record 26 of Set 9 | zhangye
# Processing Record 27 of Set 9 | comodoro rivadavia
# Processing Record 28 of Set 9 | sal rei
# Processing Record 29 of Set 9 | chaochou
# City not found. Skipping...
# Processing Record 30 of Set 9 | sorland
# Processing Record 31 of Set 9 | gladstone
# Processing Record 32 of Set 9 | ahipara
# Processing Record 33 of Set 9 | turbat
# Processing Record 34 of Set 9 | sibut
# Processing Record 35 of Set 9 | saint-denis
# Processing Record 36 of Set 9 | mulege
# Processing Record 37 of Set 9 | waipawa
# Processing Record 38 of Set 9 | iracoubo
# Processing Record 39 of Set 9 | soyo
# Processing Record 40 of Set 9 | kharian
# Processing Record 41 of Set 9 | athens
# Processing Record 42 of Set 9 | columbia
# Processing Record 43 of Set 9 | kathu
# Processing Record 44 of Set 9 | morros
# Processing Record 45 of Set 9 | north platte
# Processing Record 46 of Set 9 | pontianak
# Processing Record 47 of Set 9 | salinopolis
# Processing Record 48 of Set 9 | yantal
# Processing Record 49 of Set 9 | kalmunai
# Processing Record 50 of Set 9 | naron
# Processing Record 1 of Set 10 | naberera
# Processing Record 2 of Set 10 | luena
# Processing Record 3 of Set 10 | marigot
# Processing Record 4 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 5 of Set 10 | ilam
# Processing Record 6 of Set 10 | launceston
# Processing Record 7 of Set 10 | charters towers
# Processing Record 8 of Set 10 | nampula
# Processing Record 9 of Set 10 | ranfurly
# Processing Record 10 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 10 | cururupu
# Processing Record 12 of Set 10 | victoria
# Processing Record 13 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 14 of Set 10 | clyde river
# Processing Record 15 of Set 10 | jiwani
# Processing Record 16 of Set 10 | eyl
# Processing Record 17 of Set 10 | thinadhoo
# Processing Record 18 of Set 10 | rafaela
# Processing Record 19 of Set 10 | shalakusha
# Processing Record 20 of Set 10 | serenje
# Processing Record 21 of Set 10 | hervey bay
# Processing Record 22 of Set 10 | birr
# Processing Record 23 of Set 10 | kaduqli
# Processing Record 24 of Set 10 | amuntai
# Processing Record 25 of Set 10 | hvolsvollur
# Processing Record 26 of Set 10 | odweyne
# Processing Record 27 of Set 10 | port hedland
# Processing Record 28 of Set 10 | oxford
# Processing Record 29 of Set 10 | shitanjing
# Processing Record 30 of Set 10 | salamanca
# Processing Record 31 of Set 10 | mana
# Processing Record 32 of Set 10 | milkovo
# Processing Record 33 of Set 10 | mount isa
# Processing Record 34 of Set 10 | issoire
# Processing Record 35 of Set 10 | santa maria
# Processing Record 36 of Set 10 | mabaruma
# Processing Record 37 of Set 10 | vitoria da conquista
# Processing Record 38 of Set 10 | ostrovnoy
# Processing Record 39 of Set 10 | abu dhabi
# Processing Record 40 of Set 10 | flinders
# Processing Record 41 of Set 10 | neiafu
# Processing Record 42 of Set 10 | trincomalee
# Processing Record 43 of Set 10 | lasa
# Processing Record 44 of Set 10 | varhaug
# Processing Record 45 of Set 10 | mayo
# Processing Record 46 of Set 10 | shingu
# Processing Record 47 of Set 10 | martapura
# Processing Record 48 of Set 10 | santa cruz
# Processing Record 49 of Set 10 | korla
# Processing Record 50 of Set 10 | kangaatsiaq
# Processing Record 1 of Set 11 | armeria
# Processing Record 2 of Set 11 | kosonsoy
# Processing Record 3 of Set 11 | calama
# Processing Record 4 of Set 11 | hay river
# Processing Record 5 of Set 11 | kyra
# Processing Record 6 of Set 11 | hudiksvall
# Processing Record 7 of Set 11 | abhar
# Processing Record 8 of Set 11 | rocha
# Processing Record 9 of Set 11 | akrini
# Processing Record 10 of Set 11 | port arthur
# Processing Record 11 of Set 11 | umm lajj
# Processing Record 12 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 11 | omboue
# Processing Record 14 of Set 11 | najran
# Processing Record 15 of Set 11 | semey
# Processing Record 16 of Set 11 | dunmore east
# Processing Record 17 of Set 11 | vaitape
# Processing Record 18 of Set 11 | caravelas
# Processing Record 19 of Set 11 | berbera
# Processing Record 20 of Set 11 | sao filipe
# Processing Record 21 of Set 11 | kemi
# Processing Record 22 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 11 | husavik
# Processing Record 24 of Set 11 | mount gambier
# Processing Record 25 of Set 11 | beloha
# Processing Record 26 of Set 11 | yinchuan
# Processing Record 27 of Set 11 | moron
# Processing Record 28 of Set 11 | asosa
# Processing Record 29 of Set 11 | oranjemund
# Processing Record 30 of Set 11 | banda aceh
# Processing Record 31 of Set 11 | tocopilla
# Processing Record 32 of Set 11 | mangrol
# Processing Record 33 of Set 11 | boulsa
# Processing Record 34 of Set 11 | carauari
# Processing Record 35 of Set 11 | tazmalt
# Processing Record 36 of Set 11 | aykhal
# Processing Record 37 of Set 11 | alekseyevsk
# Processing Record 38 of Set 11 | shenjiamen
# Processing Record 39 of Set 11 | urubicha
# Processing Record 40 of Set 11 | suluq
# Processing Record 41 of Set 11 | kawambwa
# Processing Record 42 of Set 11 | chokwe
# Processing Record 43 of Set 11 | narsaq
# Processing Record 44 of Set 11 | trondheim
# Processing Record 45 of Set 11 | komsomolskiy
# Processing Record 46 of Set 11 | san cristobal
# Processing Record 47 of Set 11 | puerto baquerizo moreno
# Processing Record 48 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 11 | ngunguru
# Processing Record 50 of Set 11 | kiomboi
# Processing Record 1 of Set 12 | ust-maya
# Processing Record 2 of Set 12 | zhicheng
# Processing Record 3 of Set 12 | bela
# Processing Record 4 of Set 12 | mkushi
# Processing Record 5 of Set 12 | cabatuan
# Processing Record 6 of Set 12 | yashkul
# Processing Record 7 of Set 12 | lusambo
# Processing Record 8 of Set 12 | ugljevik
# Processing Record 9 of Set 12 | cujmir
# Processing Record 10 of Set 12 | gunjur
# Processing Record 11 of Set 12 | shinjo
# Processing Record 12 of Set 12 | south valley
# Processing Record 13 of Set 12 | dong hoi
# Processing Record 14 of Set 12 | batagay-alyta
# Processing Record 15 of Set 12 | siirt
# Processing Record 16 of Set 12 | oka
# Processing Record 17 of Set 12 | iqaluit
# Processing Record 18 of Set 12 | marsa matruh
# Processing Record 19 of Set 12 | provins
# Processing Record 20 of Set 12 | kargasok
# Processing Record 21 of Set 12 | palmer
# Processing Record 22 of Set 12 | savinka
# Processing Record 23 of Set 12 | koutiala
# Processing Record 24 of Set 12 | tashtyp
# Processing Record 25 of Set 12 | la asuncion
# Processing Record 26 of Set 12 | saint simons
# Processing Record 27 of Set 12 | ewa beach
# Processing Record 28 of Set 12 | zephyrhills
# Processing Record 29 of Set 12 | filadelfia
# Processing Record 30 of Set 12 | los alamos
# Processing Record 31 of Set 12 | gat
# Processing Record 32 of Set 12 | kashi
# Processing Record 33 of Set 12 | urengoy
# Processing Record 34 of Set 12 | ilulissat
# Processing Record 35 of Set 12 | damghan
# Processing Record 36 of Set 12 | liminangcong
# City not found. Skipping...
# Processing Record 37 of Set 12 | simav
# Processing Record 38 of Set 12 | oyem
# Processing Record 39 of Set 12 | te anau
# Processing Record 40 of Set 12 | sivaki
# Processing Record 41 of Set 12 | labuan
# Processing Record 42 of Set 12 | abbeville
# Processing Record 43 of Set 12 | baracoa
# Processing Record 44 of Set 12 | parati
# Processing Record 45 of Set 12 | surin
# Processing Record 46 of Set 12 | brandon
# Processing Record 47 of Set 12 | kupang
# Processing Record 48 of Set 12 | dustlik
# Processing Record 49 of Set 12 | saint-francois
# Processing Record 50 of Set 12 | houston
# Processing Record 1 of Set 13 | changde
# Processing Record 2 of Set 13 | gorin
# Processing Record 3 of Set 13 | moose factory
# Processing Record 4 of Set 13 | bidhuna
# Processing Record 5 of Set 13 | ilhabela
# Processing Record 6 of Set 13 | the pas
# Processing Record 7 of Set 13 | sao felix do xingu
# Processing Record 8 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 9 of Set 13 | jiayuguan
# Processing Record 10 of Set 13 | awjilah
# Processing Record 11 of Set 13 | lerwick
# Processing Record 12 of Set 13 | penapolis
# Processing Record 13 of Set 13 | kiunga
# Processing Record 14 of Set 13 | karratha
# Processing Record 15 of Set 13 | zhengjiatun
# Processing Record 16 of Set 13 | bongandanga
# Processing Record 17 of Set 13 | san policarpo
# Processing Record 18 of Set 13 | pochutla
# Processing Record 19 of Set 13 | mashhad
# Processing Record 20 of Set 13 | jardim
# Processing Record 21 of Set 13 | ushtobe
# Processing Record 22 of Set 13 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 23 of Set 13 | mayumba
# Processing Record 24 of Set 13 | zdvinsk
# Processing Record 25 of Set 13 | bemidji
# Processing Record 26 of Set 13 | mezen
# Processing Record 27 of Set 13 | kollam
# Processing Record 28 of Set 13 | rogers
# Processing Record 29 of Set 13 | zamosc
# Processing Record 30 of Set 13 | port blair
# Processing Record 31 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 32 of Set 13 | uray
# Processing Record 33 of Set 13 | corn island
# Processing Record 34 of Set 13 | plouzane
# Processing Record 35 of Set 13 | broken hill
# Processing Record 36 of Set 13 | okato
# Processing Record 37 of Set 13 | tarata
# Processing Record 38 of Set 13 | buritis
# Processing Record 39 of Set 13 | kovdor
# Processing Record 40 of Set 13 | longyan
# Processing Record 41 of Set 13 | sterling
# Processing Record 42 of Set 13 | korsakovo
# Processing Record 43 of Set 13 | mata
# Processing Record 44 of Set 13 | masakin
# Processing Record 45 of Set 13 | totskoye
# Processing Record 46 of Set 13 | kropotkin
# Processing Record 47 of Set 13 | suntar
# Processing Record 48 of Set 13 | tahta
# Processing Record 49 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 50 of Set 13 | lingao
# Processing Record 1 of Set 14 | pitimbu
# Processing Record 2 of Set 14 | saint-leu
# Processing Record 3 of Set 14 | novoilinsk
# Processing Record 4 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 14 | bay roberts
# Processing Record 6 of Set 14 | pinega
# Processing Record 7 of Set 14 | port-gentil
# Processing Record 8 of Set 14 | hirado
# Processing Record 9 of Set 14 | namwala
# Processing Record 10 of Set 14 | peniche
# Processing Record 11 of Set 14 | kautokeino
# Processing Record 12 of Set 14 | coihaique
# Processing Record 13 of Set 14 | iranshahr
# Processing Record 14 of Set 14 | hovd
# Processing Record 15 of Set 14 | kailua
# Processing Record 16 of Set 14 | moroni
# Processing Record 17 of Set 14 | sosnovo-ozerskoye
# Processing Record 18 of Set 14 | ballina
# Processing Record 19 of Set 14 | torzhok
# Processing Record 20 of Set 14 | manta
# Processing Record 21 of Set 14 | nyimba
# Processing Record 22 of Set 14 | hokitika
# Processing Record 23 of Set 14 | champerico
# Processing Record 24 of Set 14 | cascais
# Processing Record 25 of Set 14 | rong kwang
# Processing Record 26 of Set 14 | longyearbyen
# Processing Record 27 of Set 14 | cordele
# Processing Record 28 of Set 14 | vanimo
# Processing Record 29 of Set 14 | nortelandia
# Processing Record 30 of Set 14 | deming
# Processing Record 31 of Set 14 | zholymbet
# Processing Record 32 of Set 14 | rosario
# Processing Record 33 of Set 14 | jam sahib
# Processing Record 34 of Set 14 | boa vista
# Processing Record 35 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 36 of Set 14 | popondetta
# Processing Record 37 of Set 14 | pringsewu
# Processing Record 38 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 14 | kunming
# Processing Record 40 of Set 14 | mercedes
# Processing Record 41 of Set 14 | severodvinsk
# Processing Record 42 of Set 14 | nhulunbuy
# Processing Record 43 of Set 14 | maniitsoq
# Processing Record 44 of Set 14 | bilma
# Processing Record 45 of Set 14 | darhan
# Processing Record 46 of Set 14 | san carlos de bariloche
# Processing Record 47 of Set 14 | bosaso
# Processing Record 48 of Set 14 | bandarbeyla
# Processing Record 49 of Set 14 | sainte-claire
# Processing Record 50 of Set 14 | santiago del estero
# Processing Record 1 of Set 15 | altay
# Processing Record 2 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 3 of Set 15 | santa catalina
# Processing Record 4 of Set 15 | at-bashi
# Processing Record 5 of Set 15 | songea
# Processing Record 6 of Set 15 | sault sainte marie
# Processing Record 7 of Set 15 | markova
# Processing Record 8 of Set 15 | poum
# Processing Record 9 of Set 15 | chernyshevskiy
# Processing Record 10 of Set 15 | douglas
# Processing Record 11 of Set 15 | chikwawa
# Processing Record 12 of Set 15 | bogorodskoye
# Processing Record 13 of Set 15 | pasco
# Processing Record 14 of Set 15 | razole
# Processing Record 15 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 16 of Set 15 | imeni babushkina
# Processing Record 17 of Set 15 | shadegan
# Processing Record 18 of Set 15 | ayorou
# Processing Record 19 of Set 15 | vila
# Processing Record 20 of Set 15 | teya
# Processing Record 21 of Set 15 | kirakira
# Processing Record 22 of Set 15 | saint-augustin
# Processing Record 23 of Set 15 | maldonado
# Processing Record 24 of Set 15 | xai-xai
# Processing Record 25 of Set 15 | saint-louis
# Processing Record 26 of Set 15 | torbat-e jam
# Processing Record 27 of Set 15 | baculin
# Processing Record 28 of Set 15 | les cayes
# Processing Record 29 of Set 15 | aleksandrov gay
# Processing Record 30 of Set 15 | parfenyevo
# Processing Record 31 of Set 15 | esna
# Processing Record 32 of Set 15 | tura
# Processing Record 33 of Set 15 | huilong
# Processing Record 34 of Set 15 | tabou
# Processing Record 35 of Set 15 | nisia floresta
# Processing Record 36 of Set 15 | escanaba
# Processing Record 37 of Set 15 | yokadouma
# Processing Record 38 of Set 15 | wewak
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 684

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Nuuk  64.1835  -51.7216     34.41        86          75
# 1  Punta Arenas -53.1500  -70.9167     55.51        50           0
# 2      Hamilton  39.1834  -84.5333     73.63        34           0
# 3         Lagoa  39.0500  -27.9833     70.56        83          99
# 4    Solnechnyy  50.7214  136.6319     28.53        77          77
# 5  Norman Wells  65.2820 -126.8329     37.44        87          75
# 6     Hithadhoo  -0.6000   73.0833     82.33        70         100
# 7        Hasaki  35.7333  140.8333     80.22        84          91
# 8         Vaini -21.2000 -175.2000     77.16        88          40
# 9        Hobart -42.8794  147.3294     40.26        91          75
#
#    Wind Speed Country Current Description
# 0       11.50      GL       broken clouds
# 1       23.02      CL           clear sky
# 2        4.61      US           clear sky
# 3       16.40      PT     overcast clouds
# 4        3.51      RU       broken clouds
# 5       16.11      CA       broken clouds
# 6       16.91      MV     overcast clouds
# 7       12.37      JP     overcast clouds
# 8        3.44      TO    scattered clouds
# 9        6.91      AU       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Nuuk      GL  64.1835  -51.7216     34.41        86
# 1      Punta Arenas      CL -53.1500  -70.9167     55.51        50
# 2          Hamilton      US  39.1834  -84.5333     73.63        34
# 3             Lagoa      PT  39.0500  -27.9833     70.56        83
# 4        Solnechnyy      RU  50.7214  136.6319     28.53        77
# ..              ...     ...      ...       ...       ...       ...
# 679           Tabou      CI   4.4230   -7.3528     76.35        92
# 680  Nisia Floresta      BR  -6.0911  -35.2086     86.38        66
# 681        Escanaba      US  45.7453  -87.0646     76.51        48
# 682       Yokadouma      CM   3.5167   15.0500     69.06        98
# 683           Wewak      PG  -3.5534  143.6268     79.68        85
#
#      Cloudiness  Wind Speed Current Description
# 0            75       11.50       broken clouds
# 1             0       23.02           clear sky
# 2             0        4.61           clear sky
# 3            99       16.40     overcast clouds
# 4            77        3.51       broken clouds
# ..          ...         ...                 ...
# 679          80        6.13       broken clouds
# 680          21       12.01          few clouds
# 681          92        8.19     overcast clouds
# 682         100        1.34          light rain
# 683          94        6.76     overcast clouds
#
# [684 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# If the file you are working with is not in the folder you want to save, use output_data_file = "Weather_Database/WeatherPy_Database.csv"
output_data_file = "WeatherPy_Database.csv "

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file,index_label="City_ID")
